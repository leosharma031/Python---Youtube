# %%
import numpy as np
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
## .head() top 5 .tail() bottom last

# %%
df.sample(10)
# Out:
#               job_title_short  \
# 753095    Senior Data Analyst
# 319843          Data Engineer
# 529215         Data Scientist
# 155073         Data Scientist
# 769587  Senior Data Scientist
# 750257          Data Engineer
# 282869           Data Analyst
# 174399          Data Engineer
# 314480          Data Engineer
# 100951         Data Scientist
#
#                                                 job_title  \
# 753095                            Senior Data Analyst H/F
# 319843                                      Data Engineer
# 529215  GSMG Junior Data Scientist – Associate Specialist
# 155073                            Data Developer (Hybrid)
# 769587                  Senior Data Scientist (Mailchimp)
# 750257                                   Sr Data Engineer
# 282869                              Data Insights Analyst
# 174399                     Lead Data & Analytics Engineer
# 314480                        Junior Data Center Engineer
# 100951                                Lead Data Scientist
#
#                    job_location               job_via job_schedule_type  \
# 753095                 Anywhere         via HelloWork         Full-time
# 319843              Cardiff, UK         via KSNT Jobs         Full-time
# 529215          Prague, Czechia       via Trabajo.org         Full-time
# 155073      Toronto, ON, Canada           via Ladders         Full-time
# 769587              Atlanta, GA            via Indeed         Full-time
# 750257  New Delhi, Delhi, India             via Shine         Full-time
# 282869  Wellington, New Zealand  via Jobs Trabajo.org         Full-time
# 174399                 Anywhere         via Totaljobs         Full-time
# 314480                   Greece            via Indeed         Full-time
# 100951                    India          via Bayt.com         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 753095                True                   France 2023-01-25 20:48:56
# 319843               False           United Kingdom 2023-05-25 17:29:00
# 529215               False                  Czechia 2023-06-30 19:55:52
# 155073               False                   Canada 2023-02-09 08:35:13
# 769587               False  Illinois, United States 2023-09-16 01:04:28
# 750257               False                    India 2023-12-07 20:30:36
# 282869               False              New Zealand 2023-11-29 07:21:30
# 174399                True           United Kingdom 2023-09-05 15:15:34
# 314480               False                   Greece 2023-04-03 17:46:57
# 100951               False                    India 2023-09-30 00:12:58
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 753095                  False                 False          France
# 319843                   True                 False  United Kingdom
# 529215                  False                 False         Czechia
# 155073                  False                 False          Canada
# 769587                  False                 False   United States
# 750257                  False                 False           India
# 282869                   True                 False     New Zealand
# 174399                   True                 False  United Kingdom
# 314480                  False                 False          Greece
# 100951                  False                 False           India
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 753095        None              NaN              NaN
# 319843        None              NaN              NaN
# 529215        None              NaN              NaN
# 155073        year          90000.0              NaN
# 769587        None              NaN              NaN
# 750257        None              NaN              NaN
# 282869        None              NaN              NaN
# 174399        None              NaN              NaN
# 314480        None              NaN              NaN
# 100951        None              NaN              NaN
#
#                            company_name  \
# 753095                          Oodrive
# 319843                 Yolk Recruitment
# 529215                              MSD
# 155073  Jones Lang LaSalle Incorporated
# 769587                           Intuit
# 750257                         TruITeam
# 282869           New Zealand Government
# 174399                         Jet2.com
# 314480                         PrimeTel
# 100951                           Sanofi
#
#                                                job_skills  \
# 753095  ['sql', 'python', 'power bi', 'tableau', 'visi...
# 319843  ['python', 'azure', 'databricks', 'gcp', 'spark']
# 529215  ['python', 'r', 'sql', 'qlik', 'power bi', 'sap']
# 155073  ['python', 'sql', 'sql server', 'azure', 'aws'...
# 769587    ['r', 'python', 'sql', 'scikit-learn', 'linux']
# 750257   ['sql', 'python', 'gdpr', 'tableau', 'power bi']
# 282869                              ['excel', 'power bi']
# 174399  ['sql', 'snowflake', 'bigquery', 'aws', 'redsh...
# 314480                                 ['linux', 'visio']
# 100951  ['python', 'r', 'scala', 'sql', 'nosql', 'aws'...
#
#                                           job_type_skills
# 753095  {'analyst_tools': ['power bi', 'tableau', 'vis...
# 319843  {'cloud': ['azure', 'databricks', 'gcp'], 'lib...
# 529215  {'analyst_tools': ['qlik', 'power bi', 'sap'],...
# 155073  {'cloud': ['azure', 'aws'], 'databases': ['sql...
# 769587  {'libraries': ['scikit-learn'], 'os': ['linux'...
# 750257  {'analyst_tools': ['tableau', 'power bi'], 'li...
# 282869           {'analyst_tools': ['excel', 'power bi']}
# 174399  {'analyst_tools': ['word'], 'cloud': ['snowfla...
# 314480      {'analyst_tools': ['visio'], 'os': ['linux']}
# 100951  {'analyst_tools': ['tableau', 'power bi', 'dat...

# %%
df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# 780907              Data Engineer with Fivetran,Qlik Must
#
#                      job_location                 job_via job_schedule_type  \
# 502901                St Paul, MN               via BeBee         Full-time
# 406337                 London, UK            via LinkedIn         Full-time
# 659951    Newcastle upon Tyne, UK              via Indeed         Full-time
# 541593                      Malta         via Trabajo.org         Full-time
# 425158     Amsterdam, Netherlands          via NBC4i Jobs         Full-time
# 183426                  Singapore  via Singapore | JobsDB         Full-time
# 287790                  Tampa, FL            via LinkedIn         Full-time
# 541983              Chantilly, VA      via Clearance Jobs         Full-time
# 416896                     France            via LinkedIn         Full-time
# 780907  Mexico City, CDMX, Mexico        via BeBee México         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
# 183426               False               Singapore 2023-11-09 16:07:57
# 287790               False  Florida, United States 2023-07-14 17:02:23
# 541983               False                 Georgia 2023-06-15 19:44:34
# 416896               False                  France 2023-09-22 16:47:24
# 780907               False                  Mexico 2023-01-16 06:19:09
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
# 183426                  False                 False       Singapore
# 287790                   True                 False   United States
# 541983                  False                 False   United States
# 416896                  False                 False          France
# 780907                  False                 False          Mexico
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
# 183426        None              NaN              NaN    FLEXOSENSE PTE. LTD.
# 287790        None              NaN              NaN      Iris Software Inc.
# 541983        None              NaN              NaN                    SAIC
# 416896        None              NaN              NaN             KPMG France
# 780907        None              NaN              NaN        CORUS Consulting
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
# 183426  ['r', 'python', 'java', 'sql', 'sql server', '...
# 287790                         ['sql', 'hadoop', 'excel']
# 541983  ['sql', 'r', 'matlab', 'python', 'oracle', 'aw...
# 416896                                               None
# 780907  ['oracle', 'snowflake', 'aws', 'azure', 'alter...
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}
# 183426  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 287790  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 541983  {'analyst_tools': ['power bi', 'tableau', 'qli...
# 416896                                               None
# 780907  {'analyst_tools': ['alteryx'], 'cloud': ['orac...
