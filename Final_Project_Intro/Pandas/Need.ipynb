# %% [markdown]
# ## Goals

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 1. We need to look at what are the most demanded skills are for data analyst in india
# ##### 2. How in demand skills are trending.
# ##### 3. How well the job pays, by skills.
# ##### 4. What is the most optimal skill to learn for data analyst
