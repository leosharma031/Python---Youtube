# %%
import numpy as np
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import ast 
df = pd.read_csv(r"C:\Users\homeA\Desktop\Python - Youtube\data_jobs.csv")

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df = df.dropna(subset='job_skills')                ## Dropping NaN values

def clean_list(skill):                       
    return ast.literal_eval(skill)                  ## it runs this and changes String to the List data Type
df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
df['job_work_from_home'].value_counts().plot(kind='pie')
plt.title('Work from home status')
plt.ylabel("")
plt.show()

# %%
df['job_title_short'].value_counts().head(4).plot(kind='pie')
plt.title('Jobs Available in the market')
plt.ylabel("")
plt.show()

# %%
df['job_title_short'].value_counts().plot(kind='pie')
plt.title('Jobs Available in the market')
plt.ylabel("")
plt.show()

# %%
df['job_work_from_home'].value_counts().plot(kind='pie', startangle = 45, autopct='%1.1f%%')
plt.title('Work from home status')
plt.ylabel("")
plt.show()

# %%
df[['job_work_from_home', 'job_no_degree_mention' ,'job_health_insurance']]
# Out:
#         job_work_from_home  job_no_degree_mention  job_health_insurance
# 1                    False                  False                 False
# 2                    False                  False                 False
# 3                    False                   True                 False
# 4                    False                  False                 False
# 5                     True                  False                 False
# ...                    ...                    ...                   ...
# 785736               False                  False                 False
# 785737               False                  False                 False
# 785738               False                  False                 False
# 785739               False                  False                 False
# 785740               False                  False                 False
#
# [668704 rows x 3 columns]

# %%
fx, ax = plt.subplots(1,3, figsize=(8, 10))

dict = {
    'job_work_from_home':'Work From Home',
    'job_no_degree_mention':'Job Degree Requirement',
    'job_health_insurance':'Health Insurance Offered'
}

for i , (key, value) in enumerate (dict.items()):
    # print(i,key,value)
    ax[i].pie(df[key].value_counts(), startangle = 0, autopct='%1.1f%%', labels=['False','True'])
    ax[i].set_title(value)
plt.show()
